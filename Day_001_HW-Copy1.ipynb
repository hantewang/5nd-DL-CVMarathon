# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    
    """
    mse = MSE = np.sqrt(sum(pow(y - yp,2))) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 1.448
# The Mean absolute error is 11.460

# %%
作業2：申論題目可直接將答案回覆在HW檔案裡面，Jupyter notebook可直接編輯文字。

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要

我找的是Digit Recognizer 這組電腦視覺的敲門競賽, 這組重要的地方在於辨識各種手寫數字從0-9
不僅有電腦視覺必備知識,也是歷史很久的(1999)可以從這組看現在電腦視覺的演變.

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

收集各式各樣的手寫拉伯數字,例如從郵局銀行等等手寫匯款單

3. 蒐集而來的資料型態為何

0-9灰階28*28,由淺到深從0~783
來表示手寫數字的深淺以及被填滿的像素位置
有training & test set

4. 這組資料想解決的問題如何評估

拿全新的手寫資料(或者沒被訓練到的剩餘資料)去計算預估的準確率即可

# %%
作業3：申論題目可直接將答案回覆在HW檔案裡面，Jupyter notebook可直接編輯文字。

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

我想研究多趟短載(例如市區車站等候)跟長途(比如機場或者其他可能地點)
哪一種載客方案其日期地點等等與日營業額的相關

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

司機統計而來,或者如果可行分析隨車GPS資料

3. 蒐集而來的資料型態為何

會是擁有日期標籤以及多個不同屬性欄的資料(如日期地點時間等等)


4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

假設預測某種業績增長的可能性可以嘗試,然後多在那個時間地點載客
